# %%
! pip install torchvision

# %%
from torchvision import models
import torch

# %%
dir(models)
# Out:
# ['AlexNet',
#  'DenseNet',
#  'GoogLeNet',
#  'GoogLeNetOutputs',
#  'Inception3',
#  'InceptionOutputs',
#  'MNASNet',
#  'MobileNetV2',
#  'ResNet',
#  'ShuffleNetV2',
#  'SqueezeNet',
#  'VGG',
#  '_GoogLeNetOutputs',
#  '_InceptionOutputs',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '_utils',
#  'alexnet',
#  'densenet',
#  'densenet121',
#  'densenet161',
#  'densenet169',
#  'densenet201',
#  'detection',
#  'googlenet',
#  'inception',
#  'inception_v3',
#  'mnasnet',
#  'mnasnet0_5',
#  'mnasnet0_75',
#  'mnasnet1_0',
#  'mnasnet1_3',
#  'mobilenet',
#  'mobilenet_v2',
#  'quantization',
#  'resnet',
#  'resnet101',
#  'resnet152',
#  'resnet18',
#  'resnet34',
#  'resnet50',
#  'resnext101_32x8d',
#  'resnext50_32x4d',
#  'segmentation',
#  'shufflenet_v2_x0_5',
#  'shufflenet_v2_x1_0',
#  'shufflenet_v2_x1_5',
#  'shufflenet_v2_x2_0',
#  'shufflenetv2',
#  'squeezenet',
# ...

# %%
densenet = models.densenet201(pretrained=True)
# Out:
# Downloading: "https://download.pytorch.org/models/densenet201-c1103571.pth" to /root/.cache/torch/hub/checkpoints/densenet201-c1103571.pth
# ...

# %%
from PIL import Image
img = Image.open("4.jpg")

# %%
from torchvision import transforms

transform = transforms.Compose([transforms.ToTensor()])

# %%
img_t = transform(img)
batch_t = torch.unsqueeze(img_t, 0)

# %%
densenet.eval()

# %%
import numpy as np

out = densenet(batch_t).detach().numpy().ravel()
print(out.detach().numpy().ravel().shape)
# Out:
# (1000,)

# %%
embeddings = []
for i in range(1600):
  img = Image.open('drive/My Drive/Colab Notebooks/images/' + str(i) + '.jpg').convert('RGB')
  transform = transforms.Compose([transforms.ToTensor()])
  img_t = transform(img)
  batch_t = torch.unsqueeze(img_t, 0)
  vec = densenet(batch_t).detach().numpy().ravel()
  print('Vectorized: ' + str(i) + '.jpg')
  embeddings.append(vec)

# %%
import numpy as np

dense = np.array(embeddings)

# %%
import os
import pickle

pickle.dump(dense,
            open(os.path.join('densenest_embeddings.pkl'), 'wb'),
            protocol=4)

! cp densenest_embeddings.pkl ./drive/My\ Drive/Colab\ Notebooks/
